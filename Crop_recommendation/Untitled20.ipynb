# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("./crop_recommendation.csv")
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.columns = ['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','Ph_Value','Rainfall','Crop','State','City']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.columns = ['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','Ph_Value','Rainfall','Crop','State','City']
#
# File c:\Users\saroj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6310, in NDFrame.__setattr__(self, name, value)
#    6308 try:
#    6309     object.__getattribute__(self, name)
# -> 6310     return object.__setattr__(self, name, value)
#    6311 except AttributeError:
#    6312     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\saroj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
# ...

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  Ph_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop           State                City
# ...

# %%
df.shape
# Out:
# (2200, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2200 non-null   int64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   Ph_Value     2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   Crop         2200 non-null   object
#  8   State        2200 non-null   object
#  9   City         2200 non-null   object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 172.0+ KB

# %%
sns.boxplot(x= df['Nitrogen'],data=df)
# Out:
# <Axes: xlabel='Nitrogen'>

# %%
sns.boxplot(x = df['Phosphorus'],data =df)
# Out:
# <Axes: xlabel='Phosphorus'>

# %%
for col in df.columns:
    sns.boxplot(x= df[col],data=df)
    plt.title(f"The boxplot of {col} column")
    plt.show()

# %%
Q1,Q3 = np.percentile(df['Phosphorus'],[25,75])
IQR= Q3-Q1
LF= Q1-1.5 * IQR
UF = Q3 + 1.5*IQR
df= df[(df['Phosphorus'] > LF) & (df['Phosphorus'] <UF)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\saroj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Phosphorus'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
Q1,Q3 = np.percentile(df['Potassium'],[25,75])
IQR= Q3-Q1
LF= Q1-1.5 * IQR
UF = Q3 + 1.5*IQR
df= df[(df['Potassium'] > LF) & (df['Potassium'] <UF)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\saroj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Potassium'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %%
Q1,Q3 = np.percentile(df['Temperature'],[25,75])
IQR= Q3-Q1
LF= Q1-1.5 * IQR
UF = Q3 + 1.5*IQR
df=df[(df['Temperature'] > LF) & (df['Temperature'] <UF)]

# %%
Q1,Q3 = np.percentile(df['Humidity'],[25,75])
IQR= Q3-Q1
LF= Q1-1.5 * IQR
UF = Q3 + 1.5*IQR
df=df[(df['Humidity'] > LF) & (df['Humidity'] <UF)]

# %%
Q1,Q3 = np.percentile(df['Rainfall'],[25,75])
IQR= Q3-Q1
LF= Q1-1.5 * IQR
UF = Q3 + 1.5*IQR
df=df[(df['Rainfall'] > LF) & (df['Rainfall'] <UF)]

# %%
df.shape
# Out:
# (2075, 10)

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  Ph_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 13          93          56         36    24.014976  82.056872  6.984354
# 14          94          50         37    25.665852  80.663850  6.948020
# 17          91          35         39    23.793920  80.418180  6.970860
# 20          89          45         36    21.325042  80.474764  6.442475
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop           State                City
# ...

# %%
df['State'].value_counts()
# Out:
# Goa                  86
# Sikkim               78
# Rajasthan            74
# Nagaland             74
# Arunachal Pradesh    74
# Telangana            72
# Bihar                71
# Mizoram              70
# Tamil Nadu           69
# Andhra Pradesh       69
# Uttar Pradesh        69
# Himachal Pradesh     68
# Karnataka            68
# Assam                66
# Tripura              66
# Madhya Pradesh       66
# Chhattisgarh         63
# Jharkhand            61
# Delhi                61
# Odisha               61
# West Bengal          60
# Jammu and Kashmir    60
# Meghalaya            60
# Puducherry           59
# Maharashtra          59
# Haryana              58
# Kerala               58
# Ladakh               57
# Manipur              57
# Uttarakhand          56
# Punjab               56
# Gujarat              49
# Name: State, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Udaipur          52
# Pelling          35
# Bhagalpur        32
# Vasco da Gama    31
# Gwalior          31
#                  ..
# Shimla           14
# Nubra Valley     13
# Mumbai           12
# Surat            12
# Vadodara         11
# Name: City, Length: 95, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['State'] = label_encoder.fit_transform(df['State'])
df['City'] = label_encoder.fit_transform(df['City'])

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  Ph_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 13          93          56         36    24.014976  82.056872  6.984354
# 14          94          50         37    25.665852  80.663850  6.948020
# 17          91          35         39    23.793920  80.418180  6.970860
# 20          89          45         36    21.325042  80.474764  6.442475
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop  State  City
# 0     202.935536    rice     25    71
# ...

# %%
X=df.drop('Crop',axis =1 )
Y= df['Crop']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2 ,random_state = 1)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
nb_clf = GaussianNB()
lr_clf = LogisticRegression()
dt_clf = DecisionTreeClassifier()
svm_clf = SVC(kernel = 'linear',probability=True)

# %%
from sklearn.ensemble import VotingClassifier
assign = [('decision_tree',dt_clf),('naive_bayes',nb_clf),('log_reg',lr_clf),('svm',svm_clf)]
ensemble_clf = VotingClassifier(estimators=assign,voting = 'soft')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
# Fit the ensemble classifier
ensemble_clf.fit(X_train, Y_train)

# Predict on the test set
y_pred_ens = ensemble_clf.predict(X_test)

# Calculate and print the accuracy
from sklearn.metrics import accuracy_score
print("The accuracy of this model is:", accuracy_score(Y_test, y_pred_ens))
# Out:
# The accuracy of this model is: 0.9951807228915662

# %%
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  Ph_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 13          93          56         36    24.014976  82.056872  6.984354
# 14          94          50         37    25.665852  80.663850  6.948020
# 17          91          35         39    23.793920  80.418180  6.970860
# 20          89          45         36    21.325042  80.474764  6.442475
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop  State  City
# 0     202.935536    rice     25    71
# ...

# %%
import pickle
with open('final_model.pkl','wb') as file:
    pickle.dump(ensemble_clf,file)
